# %%
# !conda env list 
# !conda create --name PYTORCHVENV python=3.7.3 -y 

# !PYTHON={/opt/conda/envs/markus_venv}/bin/python
# !conda install -y -n PYTORCHVENV pytorch=1.4.0 numpy scipy pandas openpyxl seaborn matplotlib operator
# !conda env list

# %%
# !git clone https://github.com/WenjieWWJ/UCRS.git
# Out:
# Cloning into 'UCRS'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 203 (delta 1), reused 3 (delta 0), pack-reused 199
# Receiving objects: 100% (203/203), 81.09 MiB | 29.53 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# Updating files: 100% (118/118), done.

# %%
# !/opt/conda/envs/PYTORCHVENV/bin/python UCRS/code/FM_NFM/main.py --model=NFM --dataset=DIGIX --data_path "UCRS/data/" --hidden=64 --layers=3 --lr=0.01 --batch_size=256 --dropout=0.5 --lamda=0.001 --batch_norm=1 --epochs=20 --log_name=my_log --gpu=0
# Out:
# args: Namespace(activation_function='relu', batch_norm=1, batch_size=256, data_path='UCRS/data/', dataset='DIGIX', dropout='0.5', epochs=20, gpu='0', hidden_factor=64, lamda=0.001, layers='3', log_name='my_log', loss_type='log_loss', lr=0.01, model='NFM', model_path='./models/', optimizer='Adagrad', out=True, pre_train=False, pre_train_model_path='./models/', rec_result_path='./rec_results/', topN='[10, 20, 50, 100]')
# number of users: 7643
# number of items: 15526
# number of features: 23314
# data ready. costs 00: 00: 23
# Traceback (most recent call last):
#   File "UCRS/code/FM_NFM/main.py", line 166, in <module>
#     args.batch_norm, eval(args.dropout), FM_model)
#   File "/kaggle/working/UCRS/code/FM_NFM/model.py", line 34, in __init__
#     FM_modules.append(nn.Dropout(drop_prob[0]))
# TypeError: 'float' object is not subscriptable

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.current_device())
# Out:
# True
# 0

# %%
# !git clone  https://github.com/Experiment-Design/UCRS.git
import torch
import sys
sys.path.insert(0, './UCRS/code/FM_NFM')
import model
model_path = 'UCRS/code/FM_NFM/best_models/FM_amazon_book_64hidden_[64]layer_0.05lr_1024bs_[0.5,0.2]dropout_0.1lamda_1bn_1000epoch_best.pth'
model = torch.load(model_path)
model.cpu()
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/serialization.py:888: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.10/site-packages/torch/serialization.py:888: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.10/site-packages/torch/serialization.py:888: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.10/site-packages/torch/serialization.py:888: SourceChangeWarning: source code of class 'torch.nn.modules.dropout.Dropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# FM(
#   (embeddings): Embedding(45989, 64)
#   (biases): Embedding(45989, 1)
#   (FM_layers): Sequential(
#     (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
# !ls
# ad-hoc imports
# !conda install -y -n PYTORCHVENV openpyxl seaborn matplotlib

# %%
import os
print(os.getcwd())

# %% [markdown]
# # UCI Inference

# %% [markdown]
# ## item-feature controls

# %% [markdown]
# ### Reranking

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/Reranking"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_reranking.py --model=FM --dataset=ml_1m
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/Reranking
# args: Namespace(data_path='../../../../data/', dataset='ml_1m', file_head='', gpu='0', model='FM', model_path='../../../FM_NFM/best_models/', topN='[10, 20]')
# file_head FM_ml_1m_64hidden_[32]layer_0.05lr_1024bs_[0.3,0.3]dropout_0.1lamda_1bn_1500epoch
# number of users: 6040
# number of items: 3883
# number of features: 13408
# All predicted users' number is 3806
# ------------------------------------------------------
#
# ------------------------------------
# Reranking
# ------------------------------------
#
# ------------------------------
# beta 0
# [Test] Recall: 0.0659-0.1162 NDCG: 0.0536-0.0689 WNDCG: 0.0485-0.0646
# coverage_A: -5.1513 coverage: 8.66
# GA_all_avg: 0.0438 GD_all_avg(MCD): 0.5994 target_GA_avg: -0.0037 target_GD_avg(TCD): 0.2222
# ------------------------------
# beta 0.05
# [Test] Recall: 0.0758-0.1303 NDCG: 0.0633-0.0797 WNDCG: 0.0598-0.0771
# coverage_A: -4.8778 coverage: 8.9335
# GA_all_avg: -0.4111 GD_all_avg(MCD): 0.1445 target_GA_avg: 0.0777 target_GD_avg(TCD): 0.3037
# ------------------------------
# beta 0.07
# [Test] Recall: 0.0761-0.1318 NDCG: 0.0637-0.0806 WNDCG: 0.0603-0.0782
# coverage_A: -4.8705 coverage: 8.9409
# GA_all_avg: -0.4556 GD_all_avg(MCD): 0.1 target_GA_avg: 0.0839 target_GD_avg(TCD): 0.3099
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0746-0.1294 NDCG: 0.0634-0.0802 WNDCG: 0.0601-0.0779
# coverage_A: -4.8847 coverage: 8.9267
# GA_all_avg: -0.4882 GD_all_avg(MCD): 0.0674 target_GA_avg: 0.0882 target_GD_avg(TCD): 0.3142
# ------------------------------
# beta 0.5
# [Test] Recall: 0.0761-0.13 NDCG: 0.0642-0.0812 WNDCG: 0.0608-0.0789
# coverage_A: -4.8794 coverage: 8.9319
# GA_all_avg: -0.5262 GD_all_avg(MCD): 0.0294 target_GA_avg: 0.0937 target_GD_avg(TCD): 0.3197
# ------------------------------
# beta 0.75
# [Test] Recall: 0.0761-0.1301 NDCG: 0.0642-0.0812 WNDCG: 0.0608-0.079
# coverage_A: -4.8794 coverage: 8.9319
# GA_all_avg: -0.5262 GD_all_avg(MCD): 0.0294 target_GA_avg: 0.0937 target_GD_avg(TCD): 0.3197
# ------------------------------
# beta 1
# [Test] Recall: 0.0761-0.1301 NDCG: 0.0642-0.0812 WNDCG: 0.0608-0.079
# coverage_A: -4.8794 coverage: 8.9319
# GA_all_avg: -0.5262 GD_all_avg(MCD): 0.0294 target_GA_avg: 0.0937 target_GD_avg(TCD): 0.3197

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/Reranking"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_reranking.py --model=FM --dataset=amazon_book
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/Reranking
# args: Namespace(data_path='../../../../data/', dataset='amazon_book', file_head='', gpu='0', model='FM', model_path='../../../FM_NFM/best_models/', topN='[10, 20]')
# file_head FM_amazon_book_64hidden_[64]layer_0.05lr_1024bs_[0.5,0.2]dropout_0.1lamda_1bn_1000epoch
# number of users: 29115
# number of items: 16845
# number of features: 45989
# All predicted users' number is 5155
# ------------------------------------------------------
#
# ------------------------------------
# Reranking
# ------------------------------------
#
# ------------------------------
# beta 0
# [Test] Recall: 0.0118-0.0223 NDCG: 0.0095-0.0139 WNDCG: 0.0085-0.0125
# coverage_A: -2.8297 coverage: 3.0175
# GA_all_avg: 0.0372 GD_all_avg(MCD): 0.5353 target_GA_avg: -0.0198 target_GD_avg(TCD): 0.2305
# ------------------------------
# beta 0.05
# [Test] Recall: 0.0178-0.0317 NDCG: 0.0142-0.0199 WNDCG: 0.0142-0.0199
# coverage_A: -2.8241 coverage: 3.0231
# GA_all_avg: -0.4934 GD_all_avg(MCD): 0.0048 target_GA_avg: 0.2834 target_GD_avg(TCD): 0.5337
# ------------------------------
# beta 0.07
# [Test] Recall: 0.0178-0.0317 NDCG: 0.0142-0.0199 WNDCG: 0.0142-0.0199
# coverage_A: -2.8268 coverage: 3.0204
# GA_all_avg: -0.4942 GD_all_avg(MCD): 0.0039 target_GA_avg: 0.2839 target_GD_avg(TCD): 0.5342
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0178-0.0318 NDCG: 0.0142-0.0199 WNDCG: 0.0142-0.0199
# coverage_A: -2.827 coverage: 3.0202
# GA_all_avg: -0.4946 GD_all_avg(MCD): 0.0035 target_GA_avg: 0.2841 target_GD_avg(TCD): 0.5344
# ------------------------------
# beta 0.5
# [Test] Recall: 0.0178-0.0318 NDCG: 0.0142-0.0199 WNDCG: 0.0142-0.02
# coverage_A: -2.8275 coverage: 3.0196
# GA_all_avg: -0.4955 GD_all_avg(MCD): 0.0026 target_GA_avg: 0.2845 target_GD_avg(TCD): 0.5348
# ------------------------------
# beta 0.75
# [Test] Recall: 0.0178-0.0318 NDCG: 0.0142-0.0199 WNDCG: 0.0142-0.02
# coverage_A: -2.8275 coverage: 3.0196
# GA_all_avg: -0.4955 GD_all_avg(MCD): 0.0026 target_GA_avg: 0.2845 target_GD_avg(TCD): 0.5348
# ------------------------------
# beta 1
# [Test] Recall: 0.0178-0.0318 NDCG: 0.0142-0.0199 WNDCG: 0.0142-0.02
# coverage_A: -2.8275 coverage: 3.0196
# GA_all_avg: -0.4955 GD_all_avg(MCD): 0.0026 target_GA_avg: 0.2845 target_GD_avg(TCD): 0.5348

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/Reranking"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_reranking.py --model=FM --dataset=DIGIX
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/Reranking
# args: Namespace(data_path='../../../../data/', dataset='DIGIX', file_head='', gpu='0', model='FM', model_path='../../../FM_NFM/best_models/', topN='[10, 20]')
# Traceback (most recent call last):
#   File "/kaggle/working/UCRS/code/UCI/item_controls/Reranking/UCI_reranking.py", line 74, in <module>
#     print("file_head", file_head)
# NameError: name 'file_head' is not defined

# %% [markdown]
# ### Fine-grained and coarse-grained item-feature controls

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/fine_coarse_UCI"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/C_UCI_inference.py --model=FM --dataset=ml_1m
print('\n', '='*55, '\n')
# !$PY $PATH/F_UCI_inference.py --model=NFM --dataset=amazon_book
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/fine_coarse_UCI
# args: Namespace(FM_model_path='../../../FM_NFM/best_models/', TCP_model_path='./models/', act_function='sigmoid', batch_norm=1, batch_size=256, data_path='../../../../data/', dataset='ml_1m', dropout=0.1, epochs=1000, gpu='0', lamda=0.2, layers='[128]', log_name='', lr=0.01, model='FM', optimizer='Adagrad', topN='[10, 20]')
# number of users: 6040
# number of items: 3883
# number of features: 13408
# All predicted users' number is 3806
# /opt/conda/envs/PYTORCHVENV/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'model.FM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/envs/PYTORCHVENV/lib/python3.7/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# --------------------------------
# alpha 0.6
# ------------------------------------------------------------
# k: 1
# ------------------------------
# beta 0
# [Test] Recall: 0.0712-0.1198 NDCG: 0.0592-0.0742 WNDCG: 0.0541-0.07
# coverage_A: -4.0158 coverage: 9.7956
# GA_all_avg: -0.0081 GD_all_avg(MCD): 0.5475 target_GA_avg: 0.0184 target_GD_avg(TCD): 0.2444
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0732-0.1233 NDCG: 0.0641-0.0794 WNDCG: 0.0598-0.076
# coverage_A: -3.8831 coverage: 9.9283
# GA_all_avg: -0.1073 GD_all_avg(MCD): 0.4483 target_GA_avg: 0.0541 target_GD_avg(TCD): 0.2801
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0754-0.1267 NDCG: 0.0652-0.0807 WNDCG: 0.0617-0.0779
# coverage_A: -3.927 coverage: 9.8844
# GA_all_avg: -0.193 GD_all_avg(MCD): 0.3626 target_GA_avg: 0.0833 target_GD_avg(TCD): 0.3092
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0755-0.128 NDCG: 0.0647-0.0806 WNDCG: 0.0617-0.0783
# coverage_A: -4.1579 coverage: 9.6534
# GA_all_avg: -0.2611 GD_all_avg(MCD): 0.2945 target_GA_avg: 0.1027 target_GD_avg(TCD): 0.3287
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0753-0.1276 NDCG: 0.0643-0.0802 WNDCG: 0.0614-0.078
# coverage_A: -4.2606 coverage: 9.5507
# GA_all_avg: -0.2808 GD_all_avg(MCD): 0.2748 target_GA_avg: 0.1075 target_GD_avg(TCD): 0.3334
# ------------------------------------------------------------
# k: 2
# ------------------------------
# beta 0
# [Test] Recall: 0.0712-0.1198 NDCG: 0.0592-0.0742 WNDCG: 0.0541-0.07
# coverage_A: -4.0158 coverage: 9.7956
# GA_all_avg: -0.0081 GD_all_avg(MCD): 0.5475 target_GA_avg: 0.0184 target_GD_avg(TCD): 0.2444
# ------------------------------
# beta 0.03
# [Test] Recall: 0.073-0.1235 NDCG: 0.0637-0.0792 WNDCG: 0.0595-0.076
# coverage_A: -3.9511 coverage: 9.8602
# GA_all_avg: -0.1251 GD_all_avg(MCD): 0.4305 target_GA_avg: 0.0603 target_GD_avg(TCD): 0.2862
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0767-0.1273 NDCG: 0.065-0.0802 WNDCG: 0.0615-0.0776
# coverage_A: -4.154 coverage: 9.6574
# GA_all_avg: -0.2229 GD_all_avg(MCD): 0.3327 target_GA_avg: 0.0929 target_GD_avg(TCD): 0.3188
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0758-0.1294 NDCG: 0.0644-0.0806 WNDCG: 0.0613-0.0786
# coverage_A: -4.5557 coverage: 9.2556
# GA_all_avg: -0.2952 GD_all_avg(MCD): 0.2604 target_GA_avg: 0.1121 target_GD_avg(TCD): 0.3381
# ------------------------------
# beta 0.1
# [Test] Recall: 0.075-0.1295 NDCG: 0.0639-0.0803 WNDCG: 0.0609-0.0784
# coverage_A: -4.7199 coverage: 9.0914
# GA_all_avg: -0.3153 GD_all_avg(MCD): 0.2403 target_GA_avg: 0.1166 target_GD_avg(TCD): 0.3425
# ------------------------------------------------------------
# k: 3
# ------------------------------
# beta 0
# [Test] Recall: 0.0712-0.1198 NDCG: 0.0592-0.0742 WNDCG: 0.0541-0.07
# coverage_A: -4.0158 coverage: 9.7956
# GA_all_avg: -0.0081 GD_all_avg(MCD): 0.5475 target_GA_avg: 0.0184 target_GD_avg(TCD): 0.2444
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0743-0.1241 NDCG: 0.065-0.0802 WNDCG: 0.0608-0.0769
# coverage_A: -3.9866 coverage: 9.8248
# GA_all_avg: -0.1335 GD_all_avg(MCD): 0.422 target_GA_avg: 0.0607 target_GD_avg(TCD): 0.2866
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0765-0.1281 NDCG: 0.0664-0.0818 WNDCG: 0.0627-0.0791
# coverage_A: -4.2648 coverage: 9.5465
# GA_all_avg: -0.2333 GD_all_avg(MCD): 0.3223 target_GA_avg: 0.0911 target_GD_avg(TCD): 0.3171
# ------------------------------
# beta 0.09
# [Test] Recall: 0.077-0.1309 NDCG: 0.0665-0.0824 WNDCG: 0.063-0.0802
# coverage_A: -4.6908 coverage: 9.1206
# GA_all_avg: -0.309 GD_all_avg(MCD): 0.2466 target_GA_avg: 0.1075 target_GD_avg(TCD): 0.3334
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0766-0.1319 NDCG: 0.0664-0.0828 WNDCG: 0.0631-0.0807
# coverage_A: -4.8741 coverage: 8.9372
# GA_all_avg: -0.3291 GD_all_avg(MCD): 0.2265 target_GA_avg: 0.1109 target_GD_avg(TCD): 0.3368
# ------------------------------------------------------------
# k: 4
# ------------------------------
# beta 0
# [Test] Recall: 0.0712-0.1198 NDCG: 0.0592-0.0742 WNDCG: 0.0541-0.07
# coverage_A: -4.0158 coverage: 9.7956
# GA_all_avg: -0.0081 GD_all_avg(MCD): 0.5475 target_GA_avg: 0.0184 target_GD_avg(TCD): 0.2444
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0764-0.1245 NDCG: 0.066-0.0806 WNDCG: 0.0617-0.0772
# coverage_A: -3.9979 coverage: 9.8135
# GA_all_avg: -0.1392 GD_all_avg(MCD): 0.4164 target_GA_avg: 0.0611 target_GD_avg(TCD): 0.287
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0767-0.1292 NDCG: 0.0666-0.0825 WNDCG: 0.0627-0.0796
# coverage_A: -4.2985 coverage: 9.5129
# GA_all_avg: -0.2419 GD_all_avg(MCD): 0.3137 target_GA_avg: 0.0879 target_GD_avg(TCD): 0.3138
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0769-0.1309 NDCG: 0.0667-0.0829 WNDCG: 0.0631-0.0805
# coverage_A: -4.7147 coverage: 9.0967
# GA_all_avg: -0.318 GD_all_avg(MCD): 0.2376 target_GA_avg: 0.1022 target_GD_avg(TCD): 0.3282
# ------------------------------
# beta 0.1
# [Test] Recall: 0.076-0.1315 NDCG: 0.0664-0.083 WNDCG: 0.063-0.0807
# coverage_A: -4.8952 coverage: 8.9162
# GA_all_avg: -0.3394 GD_all_avg(MCD): 0.2162 target_GA_avg: 0.1055 target_GD_avg(TCD): 0.3315
# ------------------------------------------------------------
# k: 5
# ------------------------------
# beta 0
# [Test] Recall: 0.0712-0.1198 NDCG: 0.0592-0.0742 WNDCG: 0.0541-0.07
# coverage_A: -4.0158 coverage: 9.7956
# GA_all_avg: -0.0081 GD_all_avg(MCD): 0.5475 target_GA_avg: 0.0184 target_GD_avg(TCD): 0.2444
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0763-0.1239 NDCG: 0.0656-0.0799 WNDCG: 0.0613-0.0766
# coverage_A: -4.0032 coverage: 9.8082
# GA_all_avg: -0.1437 GD_all_avg(MCD): 0.4119 target_GA_avg: 0.0604 target_GD_avg(TCD): 0.2864
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0768-0.1296 NDCG: 0.0663-0.0822 WNDCG: 0.0623-0.0793
# coverage_A: -4.2803 coverage: 9.531
# GA_all_avg: -0.2463 GD_all_avg(MCD): 0.3093 target_GA_avg: 0.0864 target_GD_avg(TCD): 0.3123
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0777-0.131 NDCG: 0.0661-0.0823 WNDCG: 0.0624-0.0798
# coverage_A: -4.702 coverage: 9.1093
# GA_all_avg: -0.3211 GD_all_avg(MCD): 0.2345 target_GA_avg: 0.1006 target_GD_avg(TCD): 0.3265
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0767-0.132 NDCG: 0.0659-0.0827 WNDCG: 0.0623-0.0803
# coverage_A: -4.8613 coverage: 8.9501
# GA_all_avg: -0.3414 GD_all_avg(MCD): 0.2142 target_GA_avg: 0.1038 target_GD_avg(TCD): 0.3298
# --------------------------------
# alpha 0.7
# ------------------------------------------------------------
# k: 1
# ------------------------------
# beta 0
# [Test] Recall: 0.0701-0.1186 NDCG: 0.058-0.0729 WNDCG: 0.0528-0.0687
# coverage_A: -4.3248 coverage: 9.4866
# GA_all_avg: 0.0113 GD_all_avg(MCD): 0.5669 target_GA_avg: 0.0136 target_GD_avg(TCD): 0.2396
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0743-0.1232 NDCG: 0.0647-0.0794 WNDCG: 0.0606-0.0762
# coverage_A: -4.1253 coverage: 9.686
# GA_all_avg: -0.1108 GD_all_avg(MCD): 0.4448 target_GA_avg: 0.0583 target_GD_avg(TCD): 0.2843
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0756-0.1274 NDCG: 0.0648-0.0801 WNDCG: 0.0614-0.0776
# coverage_A: -4.2249 coverage: 9.5864
# GA_all_avg: -0.2085 GD_all_avg(MCD): 0.3471 target_GA_avg: 0.091 target_GD_avg(TCD): 0.3169
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0767-0.1297 NDCG: 0.0648-0.0806 WNDCG: 0.0618-0.0785
# coverage_A: -4.5213 coverage: 9.2901
# GA_all_avg: -0.2816 GD_all_avg(MCD): 0.2739 target_GA_avg: 0.1121 target_GD_avg(TCD): 0.3381
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0762-0.1296 NDCG: 0.0643-0.0804 WNDCG: 0.0615-0.0785
# coverage_A: -4.6343 coverage: 9.1771
# GA_all_avg: -0.3009 GD_all_avg(MCD): 0.2547 target_GA_avg: 0.1169 target_GD_avg(TCD): 0.3429
# ------------------------------------------------------------
# k: 2
# ------------------------------
# beta 0
# [Test] Recall: 0.0701-0.1186 NDCG: 0.058-0.0729 WNDCG: 0.0528-0.0687
# coverage_A: -4.3248 coverage: 9.4866
# GA_all_avg: 0.0113 GD_all_avg(MCD): 0.5669 target_GA_avg: 0.0136 target_GD_avg(TCD): 0.2396
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0752-0.1228 NDCG: 0.0644-0.0787 WNDCG: 0.0605-0.0756
# coverage_A: -4.201 coverage: 9.6104
# GA_all_avg: -0.1328 GD_all_avg(MCD): 0.4228 target_GA_avg: 0.0682 target_GD_avg(TCD): 0.2941
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0774-0.1274 NDCG: 0.0652-0.0803 WNDCG: 0.0619-0.0779
# coverage_A: -4.5134 coverage: 9.298
# GA_all_avg: -0.2426 GD_all_avg(MCD): 0.313 target_GA_avg: 0.1019 target_GD_avg(TCD): 0.3279
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0763-0.1297 NDCG: 0.0639-0.0799 WNDCG: 0.061-0.0781
# coverage_A: -4.9942 coverage: 8.8171
# GA_all_avg: -0.3173 GD_all_avg(MCD): 0.2383 target_GA_avg: 0.1217 target_GD_avg(TCD): 0.3477
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0752-0.1302 NDCG: 0.0635-0.0801 WNDCG: 0.0607-0.0785
# coverage_A: -5.1584 coverage: 8.6529
# GA_all_avg: -0.3366 GD_all_avg(MCD): 0.219 target_GA_avg: 0.1261 target_GD_avg(TCD): 0.3521
# ------------------------------------------------------------
# k: 3
# ------------------------------
# beta 0
# [Test] Recall: 0.0701-0.1186 NDCG: 0.058-0.0729 WNDCG: 0.0528-0.0687
# coverage_A: -4.3248 coverage: 9.4866
# GA_all_avg: 0.0113 GD_all_avg(MCD): 0.5669 target_GA_avg: 0.0136 target_GD_avg(TCD): 0.2396
# ------------------------------
# beta 0.03
# [Test] Recall: 0.075-0.1235 NDCG: 0.0652-0.0796 WNDCG: 0.0612-0.0765
# coverage_A: -4.242 coverage: 9.5694
# GA_all_avg: -0.1421 GD_all_avg(MCD): 0.4135 target_GA_avg: 0.0676 target_GD_avg(TCD): 0.2935
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0776-0.1288 NDCG: 0.0663-0.0817 WNDCG: 0.0628-0.0791
# coverage_A: -4.6298 coverage: 9.1816
# GA_all_avg: -0.2531 GD_all_avg(MCD): 0.3025 target_GA_avg: 0.0996 target_GD_avg(TCD): 0.3255
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0775-0.133 NDCG: 0.0659-0.0826 WNDCG: 0.0629-0.0806
# coverage_A: -5.1508 coverage: 8.6605
# GA_all_avg: -0.3314 GD_all_avg(MCD): 0.2241 target_GA_avg: 0.1162 target_GD_avg(TCD): 0.3421
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0772-0.1342 NDCG: 0.0658-0.083 WNDCG: 0.0629-0.081
# coverage_A: -5.3266 coverage: 8.4848
# GA_all_avg: -0.352 GD_all_avg(MCD): 0.2036 target_GA_avg: 0.1194 target_GD_avg(TCD): 0.3454
# ------------------------------------------------------------
# k: 4
# ------------------------------
# beta 0
# [Test] Recall: 0.0701-0.1186 NDCG: 0.058-0.0729 WNDCG: 0.0528-0.0687
# coverage_A: -4.3248 coverage: 9.4866
# GA_all_avg: 0.0113 GD_all_avg(MCD): 0.5669 target_GA_avg: 0.0136 target_GD_avg(TCD): 0.2396
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0758-0.1245 NDCG: 0.0657-0.0802 WNDCG: 0.0615-0.077
# coverage_A: -4.2593 coverage: 9.552
# GA_all_avg: -0.148 GD_all_avg(MCD): 0.4076 target_GA_avg: 0.0659 target_GD_avg(TCD): 0.2919
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0769-0.1304 NDCG: 0.0662-0.0824 WNDCG: 0.0626-0.0799
# coverage_A: -4.6482 coverage: 9.1632
# GA_all_avg: -0.261 GD_all_avg(MCD): 0.2945 target_GA_avg: 0.0951 target_GD_avg(TCD): 0.321
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0766-0.1331 NDCG: 0.0662-0.0831 WNDCG: 0.0629-0.0809
# coverage_A: -5.1768 coverage: 8.6345
# GA_all_avg: -0.341 GD_all_avg(MCD): 0.2146 target_GA_avg: 0.1091 target_GD_avg(TCD): 0.335
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0768-0.1338 NDCG: 0.0663-0.0833 WNDCG: 0.0631-0.0811
# coverage_A: -5.3576 coverage: 8.4538
# GA_all_avg: -0.3617 GD_all_avg(MCD): 0.1939 target_GA_avg: 0.1128 target_GD_avg(TCD): 0.3388
# ------------------------------------------------------------
# k: 5
# ------------------------------
# beta 0
# [Test] Recall: 0.0701-0.1186 NDCG: 0.058-0.0729 WNDCG: 0.0528-0.0687
# coverage_A: -4.3248 coverage: 9.4866
# GA_all_avg: 0.0113 GD_all_avg(MCD): 0.5669 target_GA_avg: 0.0136 target_GD_avg(TCD): 0.2396
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0762-0.1254 NDCG: 0.0656-0.0803 WNDCG: 0.0614-0.0772
# coverage_A: -4.2528 coverage: 9.5586
# GA_all_avg: -0.1527 GD_all_avg(MCD): 0.4028 target_GA_avg: 0.0655 target_GD_avg(TCD): 0.2914
# ------------------------------
# beta 0.06
# [Test] Recall: 0.077-0.1311 NDCG: 0.0657-0.0823 WNDCG: 0.0619-0.0798
# coverage_A: -4.6193 coverage: 9.1921
# GA_all_avg: -0.2663 GD_all_avg(MCD): 0.2893 target_GA_avg: 0.092 target_GD_avg(TCD): 0.3179
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0771-0.1339 NDCG: 0.0659-0.083 WNDCG: 0.0624-0.0807
# coverage_A: -5.1398 coverage: 8.6716
# GA_all_avg: -0.3433 GD_all_avg(MCD): 0.2123 target_GA_avg: 0.1055 target_GD_avg(TCD): 0.3315
# ------------------------------
# beta 0.1
# [Test] Recall: 0.076-0.1333 NDCG: 0.0654-0.0826 WNDCG: 0.062-0.0804
# coverage_A: -5.3132 coverage: 8.4982
# GA_all_avg: -0.3633 GD_all_avg(MCD): 0.1923 target_GA_avg: 0.1081 target_GD_avg(TCD): 0.3341
# --------------------------------
# alpha 0.8
# ------------------------------------------------------------
# k: 1
# ------------------------------
# beta 0
# [Test] Recall: 0.0697-0.1189 NDCG: 0.0565-0.0716 WNDCG: 0.0514-0.0673
# coverage_A: -4.6245 coverage: 9.1868
# GA_all_avg: 0.0251 GD_all_avg(MCD): 0.5806 target_GA_avg: 0.0072 target_GD_avg(TCD): 0.2331
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0748-0.1245 NDCG: 0.064-0.0788 WNDCG: 0.0603-0.0758
# coverage_A: -4.3439 coverage: 9.4674
# GA_all_avg: -0.1268 GD_all_avg(MCD): 0.4288 target_GA_avg: 0.0651 target_GD_avg(TCD): 0.291
# ------------------------------
# beta 0.06
# [Test] Recall: 0.077-0.1289 NDCG: 0.0644-0.0796 WNDCG: 0.0612-0.0774
# coverage_A: -4.5659 coverage: 9.2454
# GA_all_avg: -0.2353 GD_all_avg(MCD): 0.3203 target_GA_avg: 0.0999 target_GD_avg(TCD): 0.3259
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0769-0.1315 NDCG: 0.0637-0.0803 WNDCG: 0.0611-0.0786
# coverage_A: -4.9503 coverage: 8.861
# GA_all_avg: -0.3068 GD_all_avg(MCD): 0.2488 target_GA_avg: 0.1192 target_GD_avg(TCD): 0.3452
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0762-0.1311 NDCG: 0.0634-0.08 WNDCG: 0.0609-0.0785
# coverage_A: -5.1104 coverage: 8.701
# GA_all_avg: -0.3247 GD_all_avg(MCD): 0.2308 target_GA_avg: 0.1234 target_GD_avg(TCD): 0.3494
# ------------------------------------------------------------
# k: 2
# ------------------------------
# beta 0
# [Test] Recall: 0.0697-0.1189 NDCG: 0.0565-0.0716 WNDCG: 0.0514-0.0673
# coverage_A: -4.6245 coverage: 9.1868
# GA_all_avg: 0.0251 GD_all_avg(MCD): 0.5806 target_GA_avg: 0.0072 target_GD_avg(TCD): 0.2331
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0751-0.1255 NDCG: 0.0636-0.0788 WNDCG: 0.0598-0.0759
# coverage_A: -4.4522 coverage: 9.3592
# GA_all_avg: -0.1516 GD_all_avg(MCD): 0.404 target_GA_avg: 0.0767 target_GD_avg(TCD): 0.3027
# ------------------------------
# beta 0.06
# [Test] Recall: 0.077-0.1293 NDCG: 0.0637-0.0796 WNDCG: 0.0607-0.0775
# coverage_A: -4.938 coverage: 8.8734
# GA_all_avg: -0.2716 GD_all_avg(MCD): 0.2839 target_GA_avg: 0.1122 target_GD_avg(TCD): 0.3382
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0762-0.1301 NDCG: 0.0632-0.0795 WNDCG: 0.0607-0.078
# coverage_A: -5.5402 coverage: 8.2712
# GA_all_avg: -0.3437 GD_all_avg(MCD): 0.2119 target_GA_avg: 0.1302 target_GD_avg(TCD): 0.3561
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0753-0.1295 NDCG: 0.0628-0.0792 WNDCG: 0.0604-0.0777
# coverage_A: -5.7465 coverage: 8.0649
# GA_all_avg: -0.3619 GD_all_avg(MCD): 0.1937 target_GA_avg: 0.1347 target_GD_avg(TCD): 0.3607
# ------------------------------------------------------------
# k: 3
# ------------------------------
# beta 0
# [Test] Recall: 0.0697-0.1189 NDCG: 0.0565-0.0716 WNDCG: 0.0514-0.0673
# coverage_A: -4.6245 coverage: 9.1868
# GA_all_avg: 0.0251 GD_all_avg(MCD): 0.5806 target_GA_avg: 0.0072 target_GD_avg(TCD): 0.2331
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0761-0.1247 NDCG: 0.0648-0.0793 WNDCG: 0.061-0.0764
# coverage_A: -4.5342 coverage: 9.2772
# GA_all_avg: -0.1622 GD_all_avg(MCD): 0.3934 target_GA_avg: 0.0757 target_GD_avg(TCD): 0.3017
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0773-0.1313 NDCG: 0.0653-0.0815 WNDCG: 0.0621-0.0792
# coverage_A: -5.0596 coverage: 8.7517
# GA_all_avg: -0.2844 GD_all_avg(MCD): 0.2712 target_GA_avg: 0.1092 target_GD_avg(TCD): 0.3352
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0766-0.1328 NDCG: 0.0649-0.0821 WNDCG: 0.062-0.0803
# coverage_A: -5.6629 coverage: 8.1484
# GA_all_avg: -0.3595 GD_all_avg(MCD): 0.1961 target_GA_avg: 0.1236 target_GD_avg(TCD): 0.3495
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0754-0.1321 NDCG: 0.0643-0.0817 WNDCG: 0.0614-0.0799
# coverage_A: -5.8747 coverage: 7.9367
# GA_all_avg: -0.3772 GD_all_avg(MCD): 0.1784 target_GA_avg: 0.1256 target_GD_avg(TCD): 0.3516
# ------------------------------------------------------------
# k: 4
# ------------------------------
# beta 0
# [Test] Recall: 0.0697-0.1189 NDCG: 0.0565-0.0716 WNDCG: 0.0514-0.0673
# coverage_A: -4.6245 coverage: 9.1868
# GA_all_avg: 0.0251 GD_all_avg(MCD): 0.5806 target_GA_avg: 0.0072 target_GD_avg(TCD): 0.2331
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0765-0.125 NDCG: 0.0653-0.08 WNDCG: 0.0614-0.077
# coverage_A: -4.5294 coverage: 9.2819
# GA_all_avg: -0.1691 GD_all_avg(MCD): 0.3865 target_GA_avg: 0.0743 target_GD_avg(TCD): 0.3003
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0768-0.1316 NDCG: 0.066-0.0825 WNDCG: 0.0626-0.08
# coverage_A: -5.078 coverage: 8.7333
# GA_all_avg: -0.2919 GD_all_avg(MCD): 0.2636 target_GA_avg: 0.1038 target_GD_avg(TCD): 0.3297
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0755-0.1342 NDCG: 0.0652-0.0831 WNDCG: 0.0621-0.0809
# coverage_A: -5.6929 coverage: 8.1185
# GA_all_avg: -0.3682 GD_all_avg(MCD): 0.1874 target_GA_avg: 0.1155 target_GD_avg(TCD): 0.3415
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0745-0.1333 NDCG: 0.0647-0.0826 WNDCG: 0.0616-0.0805
# coverage_A: -5.891 coverage: 7.9204
# GA_all_avg: -0.3857 GD_all_avg(MCD): 0.1699 target_GA_avg: 0.118 target_GD_avg(TCD): 0.344
# ------------------------------------------------------------
# k: 5
# ------------------------------
# beta 0
# [Test] Recall: 0.0697-0.1189 NDCG: 0.0565-0.0716 WNDCG: 0.0514-0.0673
# coverage_A: -4.6245 coverage: 9.1868
# GA_all_avg: 0.0251 GD_all_avg(MCD): 0.5806 target_GA_avg: 0.0072 target_GD_avg(TCD): 0.2331
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0759-0.1261 NDCG: 0.0648-0.08 WNDCG: 0.0609-0.077
# coverage_A: -4.5376 coverage: 9.2738
# GA_all_avg: -0.1743 GD_all_avg(MCD): 0.3812 target_GA_avg: 0.0728 target_GD_avg(TCD): 0.2988
# ------------------------------
# beta 0.06
# [Test] Recall: 0.078-0.1311 NDCG: 0.0658-0.0821 WNDCG: 0.0624-0.0797
# coverage_A: -5.0415 coverage: 8.7698
# GA_all_avg: -0.2955 GD_all_avg(MCD): 0.2601 target_GA_avg: 0.1001 target_GD_avg(TCD): 0.326
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0756-0.1344 NDCG: 0.0646-0.0827 WNDCG: 0.0614-0.0805
# coverage_A: -5.6293 coverage: 8.1821
# GA_all_avg: -0.3693 GD_all_avg(MCD): 0.1863 target_GA_avg: 0.112 target_GD_avg(TCD): 0.338
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0753-0.1338 NDCG: 0.0643-0.0824 WNDCG: 0.0612-0.0802
# coverage_A: -5.8074 coverage: 8.0039
# GA_all_avg: -0.3862 GD_all_avg(MCD): 0.1694 target_GA_avg: 0.1147 target_GD_avg(TCD): 0.3406
# --------------------------------
# alpha 0.9
# ------------------------------------------------------------
# k: 1
# ------------------------------
# beta 0
# [Test] Recall: 0.0682-0.1176 NDCG: 0.055-0.0701 WNDCG: 0.0499-0.0659
# coverage_A: -4.8928 coverage: 8.9185
# GA_all_avg: 0.0367 GD_all_avg(MCD): 0.5923 target_GA_avg: 0.002 target_GD_avg(TCD): 0.228
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0747-0.124 NDCG: 0.063-0.0777 WNDCG: 0.0596-0.0749
# coverage_A: -4.613 coverage: 9.1984
# GA_all_avg: -0.1543 GD_all_avg(MCD): 0.4013 target_GA_avg: 0.0746 target_GD_avg(TCD): 0.3005
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0775-0.1298 NDCG: 0.0636-0.0793 WNDCG: 0.0607-0.0773
# coverage_A: -4.9729 coverage: 8.8384
# GA_all_avg: -0.2696 GD_all_avg(MCD): 0.2859 target_GA_avg: 0.1101 target_GD_avg(TCD): 0.3361
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0765-0.1321 NDCG: 0.0618-0.0787 WNDCG: 0.0593-0.0773
# coverage_A: -5.4798 coverage: 8.3316
# GA_all_avg: -0.3372 GD_all_avg(MCD): 0.2184 target_GA_avg: 0.1257 target_GD_avg(TCD): 0.3517
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0757-0.1319 NDCG: 0.0613-0.0785 WNDCG: 0.0589-0.0772
# coverage_A: -5.644 coverage: 8.1674
# GA_all_avg: -0.353 GD_all_avg(MCD): 0.2026 target_GA_avg: 0.1281 target_GD_avg(TCD): 0.354
# ------------------------------------------------------------
# k: 2
# ------------------------------
# beta 0
# [Test] Recall: 0.0682-0.1176 NDCG: 0.055-0.0701 WNDCG: 0.0499-0.0659
# coverage_A: -4.8928 coverage: 8.9185
# GA_all_avg: 0.0367 GD_all_avg(MCD): 0.5923 target_GA_avg: 0.002 target_GD_avg(TCD): 0.228
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0753-0.1272 NDCG: 0.0627-0.0784 WNDCG: 0.0593-0.0758
# coverage_A: -4.7853 coverage: 9.026
# GA_all_avg: -0.1842 GD_all_avg(MCD): 0.3713 target_GA_avg: 0.0874 target_GD_avg(TCD): 0.3134
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0767-0.1301 NDCG: 0.0626-0.079 WNDCG: 0.0599-0.0773
# coverage_A: -5.4645 coverage: 8.3468
# GA_all_avg: -0.306 GD_all_avg(MCD): 0.2496 target_GA_avg: 0.1235 target_GD_avg(TCD): 0.3495
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0743-0.1311 NDCG: 0.0613-0.0787 WNDCG: 0.0591-0.0774
# coverage_A: -6.1169 coverage: 7.6944
# GA_all_avg: -0.3709 GD_all_avg(MCD): 0.1847 target_GA_avg: 0.1384 target_GD_avg(TCD): 0.3644
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0714-0.1309 NDCG: 0.0598-0.0781 WNDCG: 0.0577-0.0769
# coverage_A: -6.3187 coverage: 7.4926
# GA_all_avg: -0.3863 GD_all_avg(MCD): 0.1693 target_GA_avg: 0.1404 target_GD_avg(TCD): 0.3663
# ------------------------------------------------------------
# k: 3
# ------------------------------
# beta 0
# [Test] Recall: 0.0682-0.1176 NDCG: 0.055-0.0701 WNDCG: 0.0499-0.0659
# coverage_A: -4.8928 coverage: 8.9185
# GA_all_avg: 0.0367 GD_all_avg(MCD): 0.5923 target_GA_avg: 0.002 target_GD_avg(TCD): 0.228
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0761-0.1269 NDCG: 0.064-0.0793 WNDCG: 0.0606-0.0766
# coverage_A: -4.856 coverage: 8.9553
# GA_all_avg: -0.1943 GD_all_avg(MCD): 0.3612 target_GA_avg: 0.0853 target_GD_avg(TCD): 0.3112
# ------------------------------
# beta 0.06
# [Test] Recall: 0.076-0.131 NDCG: 0.0639-0.0809 WNDCG: 0.0609-0.0789
# coverage_A: -5.5565 coverage: 8.2549
# GA_all_avg: -0.3194 GD_all_avg(MCD): 0.2362 target_GA_avg: 0.1182 target_GD_avg(TCD): 0.3441
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0734-0.1329 NDCG: 0.0626-0.0808 WNDCG: 0.06-0.079
# coverage_A: -6.2759 coverage: 7.5355
# GA_all_avg: -0.3861 GD_all_avg(MCD): 0.1695 target_GA_avg: 0.128 target_GD_avg(TCD): 0.354
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0729-0.1327 NDCG: 0.062-0.0803 WNDCG: 0.0594-0.0786
# coverage_A: -6.4979 coverage: 7.3135
# GA_all_avg: -0.4013 GD_all_avg(MCD): 0.1543 target_GA_avg: 0.1304 target_GD_avg(TCD): 0.3564
# ------------------------------------------------------------
# k: 4
# ------------------------------
# beta 0
# [Test] Recall: 0.0682-0.1176 NDCG: 0.055-0.0701 WNDCG: 0.0499-0.0659
# coverage_A: -4.8928 coverage: 8.9185
# GA_all_avg: 0.0367 GD_all_avg(MCD): 0.5923 target_GA_avg: 0.002 target_GD_avg(TCD): 0.228
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0759-0.1274 NDCG: 0.064-0.0796 WNDCG: 0.0605-0.0768
# coverage_A: -4.8739 coverage: 8.9375
# GA_all_avg: -0.2013 GD_all_avg(MCD): 0.3543 target_GA_avg: 0.0819 target_GD_avg(TCD): 0.3078
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0772-0.1326 NDCG: 0.0649-0.0816 WNDCG: 0.0618-0.0795
# coverage_A: -5.572 coverage: 8.2394
# GA_all_avg: -0.3273 GD_all_avg(MCD): 0.2283 target_GA_avg: 0.1106 target_GD_avg(TCD): 0.3365
# ------------------------------
# beta 0.09
# [Test] Recall: 0.073-0.1333 NDCG: 0.0635-0.0816 WNDCG: 0.0605-0.0797
# coverage_A: -6.2549 coverage: 7.5565
# GA_all_avg: -0.3924 GD_all_avg(MCD): 0.1632 target_GA_avg: 0.1197 target_GD_avg(TCD): 0.3456
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0726-0.1328 NDCG: 0.0628-0.081 WNDCG: 0.0599-0.0791
# coverage_A: -6.4574 coverage: 7.3539
# GA_all_avg: -0.4077 GD_all_avg(MCD): 0.1479 target_GA_avg: 0.1214 target_GD_avg(TCD): 0.3474
# ------------------------------------------------------------
# k: 5
# ------------------------------
# beta 0
# [Test] Recall: 0.0682-0.1176 NDCG: 0.055-0.0701 WNDCG: 0.0499-0.0659
# coverage_A: -4.8928 coverage: 8.9185
# GA_all_avg: 0.0367 GD_all_avg(MCD): 0.5923 target_GA_avg: 0.002 target_GD_avg(TCD): 0.228
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0765-0.1287 NDCG: 0.0639-0.0799 WNDCG: 0.0603-0.0771
# coverage_A: -4.8547 coverage: 8.9566
# GA_all_avg: -0.2052 GD_all_avg(MCD): 0.3503 target_GA_avg: 0.0812 target_GD_avg(TCD): 0.3072
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0756-0.133 NDCG: 0.0642-0.0815 WNDCG: 0.0609-0.0792
# coverage_A: -5.5255 coverage: 8.2859
# GA_all_avg: -0.3301 GD_all_avg(MCD): 0.2254 target_GA_avg: 0.1066 target_GD_avg(TCD): 0.3326
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0735-0.1339 NDCG: 0.0632-0.0816 WNDCG: 0.0602-0.0796
# coverage_A: -6.1752 coverage: 7.6361
# GA_all_avg: -0.3954 GD_all_avg(MCD): 0.1602 target_GA_avg: 0.1175 target_GD_avg(TCD): 0.3435
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0734-0.1324 NDCG: 0.0628-0.0808 WNDCG: 0.0597-0.0789
# coverage_A: -6.3484 coverage: 7.463
# GA_all_avg: -0.4089 GD_all_avg(MCD): 0.1467 target_GA_avg: 0.1187 target_GD_avg(TCD): 0.3447
# --------------------------------
# alpha 1.0
# ------------------------------------------------------------
# k: 1
# ------------------------------
# beta 0
# [Test] Recall: 0.0659-0.1162 NDCG: 0.0536-0.0689 WNDCG: 0.0485-0.0646
# coverage_A: -5.1513 coverage: 8.66
# GA_all_avg: 0.0438 GD_all_avg(MCD): 0.5994 target_GA_avg: -0.0037 target_GD_avg(TCD): 0.2222
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0742-0.1265 NDCG: 0.0616-0.0771 WNDCG: 0.0584-0.0747
# coverage_A: -4.9033 coverage: 8.908
# GA_all_avg: -0.1911 GD_all_avg(MCD): 0.3645 target_GA_avg: 0.0866 target_GD_avg(TCD): 0.3126
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0777-0.1298 NDCG: 0.0623-0.0781 WNDCG: 0.0597-0.0763
# coverage_A: -5.4251 coverage: 8.3862
# GA_all_avg: -0.3066 GD_all_avg(MCD): 0.249 target_GA_avg: 0.1203 target_GD_avg(TCD): 0.3462
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0766-0.1302 NDCG: 0.0608-0.0769 WNDCG: 0.0585-0.0757
# coverage_A: -5.9976 coverage: 7.8137
# GA_all_avg: -0.366 GD_all_avg(MCD): 0.1896 target_GA_avg: 0.1311 target_GD_avg(TCD): 0.357
# ------------------------------
# beta 0.1
# [Test] Recall: 0.074-0.1298 NDCG: 0.0594-0.0766 WNDCG: 0.0573-0.0754
# coverage_A: -6.1797 coverage: 7.6316
# GA_all_avg: -0.379 GD_all_avg(MCD): 0.1766 target_GA_avg: 0.1329 target_GD_avg(TCD): 0.3589
# ------------------------------------------------------------
# k: 2
# ------------------------------
# beta 0
# [Test] Recall: 0.0659-0.1162 NDCG: 0.0536-0.0689 WNDCG: 0.0485-0.0646
# coverage_A: -5.1513 coverage: 8.66
# GA_all_avg: 0.0438 GD_all_avg(MCD): 0.5994 target_GA_avg: -0.0037 target_GD_avg(TCD): 0.2222
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0747-0.126 NDCG: 0.0615-0.0771 WNDCG: 0.0584-0.0748
# coverage_A: -5.185 coverage: 8.6264
# GA_all_avg: -0.2248 GD_all_avg(MCD): 0.3307 target_GA_avg: 0.1002 target_GD_avg(TCD): 0.3262
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0766-0.1298 NDCG: 0.0618-0.078 WNDCG: 0.0594-0.0765
# coverage_A: -5.9908 coverage: 7.8205
# GA_all_avg: -0.3393 GD_all_avg(MCD): 0.2163 target_GA_avg: 0.1325 target_GD_avg(TCD): 0.3585
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0716-0.1294 NDCG: 0.0589-0.0769 WNDCG: 0.0568-0.0758
# coverage_A: -6.7344 coverage: 7.077
# GA_all_avg: -0.398 GD_all_avg(MCD): 0.1576 target_GA_avg: 0.1422 target_GD_avg(TCD): 0.3681
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0711-0.1286 NDCG: 0.0581-0.0762 WNDCG: 0.0561-0.0751
# coverage_A: -6.9485 coverage: 6.8628
# GA_all_avg: -0.4109 GD_all_avg(MCD): 0.1447 target_GA_avg: 0.1447 target_GD_avg(TCD): 0.3706
# ------------------------------------------------------------
# k: 3
# ------------------------------
# beta 0
# [Test] Recall: 0.0659-0.1162 NDCG: 0.0536-0.0689 WNDCG: 0.0485-0.0646
# coverage_A: -5.1513 coverage: 8.66
# GA_all_avg: 0.0438 GD_all_avg(MCD): 0.5994 target_GA_avg: -0.0037 target_GD_avg(TCD): 0.2222
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0746-0.1284 NDCG: 0.0626-0.0789 WNDCG: 0.0594-0.0765
# coverage_A: -5.2599 coverage: 8.5515
# GA_all_avg: -0.2347 GD_all_avg(MCD): 0.3209 target_GA_avg: 0.097 target_GD_avg(TCD): 0.3229
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0745-0.1302 NDCG: 0.0625-0.0798 WNDCG: 0.0597-0.0781
# coverage_A: -6.1059 coverage: 7.7055
# GA_all_avg: -0.3533 GD_all_avg(MCD): 0.2022 target_GA_avg: 0.1246 target_GD_avg(TCD): 0.3506
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0708-0.1313 NDCG: 0.0599-0.0786 WNDCG: 0.0574-0.0771
# coverage_A: -6.8589 coverage: 6.9524
# GA_all_avg: -0.4108 GD_all_avg(MCD): 0.1448 target_GA_avg: 0.1308 target_GD_avg(TCD): 0.3567
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0711-0.1297 NDCG: 0.0596-0.0778 WNDCG: 0.0571-0.0763
# coverage_A: -7.0754 coverage: 6.7359
# GA_all_avg: -0.4243 GD_all_avg(MCD): 0.1312 target_GA_avg: 0.1321 target_GD_avg(TCD): 0.358
# ------------------------------------------------------------
# k: 4
# ------------------------------
# beta 0
# [Test] Recall: 0.0659-0.1162 NDCG: 0.0536-0.0689 WNDCG: 0.0485-0.0646
# coverage_A: -5.1513 coverage: 8.66
# GA_all_avg: 0.0438 GD_all_avg(MCD): 0.5994 target_GA_avg: -0.0037 target_GD_avg(TCD): 0.2222
# ------------------------------
# beta 0.03
# [Test] Recall: 0.074-0.1267 NDCG: 0.0623-0.0785 WNDCG: 0.059-0.076
# coverage_A: -5.2659 coverage: 8.5455
# GA_all_avg: -0.2417 GD_all_avg(MCD): 0.3139 target_GA_avg: 0.0928 target_GD_avg(TCD): 0.3188
# ------------------------------
# beta 0.06
# [Test] Recall: 0.073-0.1325 NDCG: 0.0626-0.0808 WNDCG: 0.0596-0.0788
# coverage_A: -6.1169 coverage: 7.6944
# GA_all_avg: -0.3603 GD_all_avg(MCD): 0.1952 target_GA_avg: 0.1168 target_GD_avg(TCD): 0.3428
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0723-0.1326 NDCG: 0.062-0.0802 WNDCG: 0.0591-0.0784
# coverage_A: -6.8245 coverage: 6.9869
# GA_all_avg: -0.4163 GD_all_avg(MCD): 0.1393 target_GA_avg: 0.1234 target_GD_avg(TCD): 0.3494
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0715-0.1317 NDCG: 0.0613-0.0796 WNDCG: 0.0585-0.0777
# coverage_A: -7.0242 coverage: 6.7872
# GA_all_avg: -0.428 GD_all_avg(MCD): 0.1275 target_GA_avg: 0.1252 target_GD_avg(TCD): 0.3511
# ------------------------------------------------------------
# k: 5
# ------------------------------
# beta 0
# [Test] Recall: 0.0659-0.1162 NDCG: 0.0536-0.0689 WNDCG: 0.0485-0.0646
# coverage_A: -5.1513 coverage: 8.66
# GA_all_avg: 0.0438 GD_all_avg(MCD): 0.5994 target_GA_avg: -0.0037 target_GD_avg(TCD): 0.2222
# ------------------------------
# beta 0.03
# [Test] Recall: 0.0745-0.1283 NDCG: 0.0623-0.0791 WNDCG: 0.0589-0.0765
# coverage_A: -5.2436 coverage: 8.5678
# GA_all_avg: -0.2457 GD_all_avg(MCD): 0.3099 target_GA_avg: 0.0912 target_GD_avg(TCD): 0.3172
# ------------------------------
# beta 0.06
# [Test] Recall: 0.0742-0.1345 NDCG: 0.0624-0.081 WNDCG: 0.0595-0.0788
# coverage_A: -6.0565 coverage: 7.7549
# GA_all_avg: -0.363 GD_all_avg(MCD): 0.1925 target_GA_avg: 0.1142 target_GD_avg(TCD): 0.3402
# ------------------------------
# beta 0.09
# [Test] Recall: 0.0712-0.1327 NDCG: 0.061-0.08 WNDCG: 0.0581-0.078
# coverage_A: -6.6989 coverage: 7.1125
# GA_all_avg: -0.4171 GD_all_avg(MCD): 0.1385 target_GA_avg: 0.1207 target_GD_avg(TCD): 0.3467
# ------------------------------
# beta 0.1
# [Test] Recall: 0.0704-0.1306 NDCG: 0.0604-0.0792 WNDCG: 0.0576-0.0772
# coverage_A: -6.8715 coverage: 6.9398
# GA_all_avg: -0.4292 GD_all_avg(MCD): 0.1264 target_GA_avg: 0.1219 target_GD_avg(TCD): 0.3479
# args: Namespace(FM_model_path='../../../FM_NFM/best_models/', TCP_model_path='./models/', act_function='sigmoid', batch_norm=1, batch_size=256, data_path='../../../../data/', dataset='amazon_book', dropout=0.1, epochs=1000, gpu='0', lamda=0.2, layers='[128]', log_name='', lr=0.01, model='NFM', optimizer='Adagrad', topN='[10, 20]')
# number of users: 29115
# number of items: 16845
# number of features: 45989
# All predicted users' number is 5155
# /opt/conda/envs/PYTORCHVENV/lib/python3.7/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# --------------------------------
# alpha 0.9
# ------------------------------
# beta 0.5
# [Test] Recall: 0.0311-0.05 NDCG: 0.0259-0.0335 WNDCG: 0.0306-0.0394
# coverage_A: -4.7651 coverage: 1.0821
# GA_all_avg: -0.4865 GD_all_avg(MCD): 0.0117 target_GA_avg: 0.7319 target_GD_avg(TCD): 0.9822
# ------------------------------
# beta 1.0
# [Test] Recall: 0.0333-0.0542 NDCG: 0.0272-0.0355 WNDCG: 0.0323-0.0423
# coverage_A: -4.8469 coverage: 1.0002
# GA_all_avg: -0.4958 GD_all_avg(MCD): 0.0023 target_GA_avg: 0.7497 target_GD_avg(TCD): 1.0
# --------------------------------
# alpha 1.0
# ------------------------------
# beta 0.5
# [Test] Recall: 0.0319-0.0514 NDCG: 0.0265-0.0342 WNDCG: 0.0312-0.0404
# coverage_A: -4.7822 coverage: 1.065
# GA_all_avg: -0.4882 GD_all_avg(MCD): 0.01 target_GA_avg: 0.7351 target_GD_avg(TCD): 0.9854
# ------------------------------
# beta 1.0
# [Test] Recall: 0.0338-0.0547 NDCG: 0.0276-0.0359 WNDCG: 0.0327-0.0426
# coverage_A: -4.8469 coverage: 1.0002
# GA_all_avg: -0.4958 GD_all_avg(MCD): 0.0023 target_GA_avg: 0.7497 target_GD_avg(TCD): 1.0

# %% [markdown]
# ## User-feature coarse-grained controls

# %% [markdown]
# ### UCI and maskUF for FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_coarse_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_coarse_user_control.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_coarse_controls
# args: Namespace(data_path='../../../data/', dataset='DIGIX', file_head='', gpu='0', model='FM', model_path='../../FM_NFM/best_models/', topN='[10, 20]')
# FM_DIGIX_64hidden_[64]layer_0.01lr_1024bs_[0.5,0.2]dropout_0.0lamda_1bn_500epoch_UF_min
# number of users: 7643
# number of items: 15526
# number of features: 23314
# --------------------------------
# alpha 0.8
# [[471, 2], ['1', '1']]
# All predicted users' number is 4768
# [Test] Recall: 0.0767-0.1168 NDCG: 0.0592-0.0731
# Cov_A -7.9694 Cov 9.8802
# his-pred isolation 0.2181 0.0777
# --------------------------------
# alpha 1.0
# [[471, 2], ['1', '1']]
# All predicted users' number is 4768
# [Test] Recall: 0.0756-0.1166 NDCG: 0.0577-0.0719
# Cov_A -8.2311 Cov 9.6185
# his-pred isolation 0.2181 0.1048

# %% [markdown]
# ### Inference for vanilla FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_coarse_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_coarse_controls
# args: Namespace(data_path='../../../data/', dataset='DIGIX', file_head='', gpu='0', model='FM', model_path='../../FM_NFM/best_models/', topN='[10, 20]')
# FM_DIGIX_64hidden_[64]layer_0.01lr_1024bs_[0.5,0.2]dropout_0.0lamda_1bn_500epoch_UF_min
# number of users: 7643
# number of items: 15526
# number of features: 23314
# All predicted users' number is 4768
# ------------------------------------------------------
# brefore reranking
# [Test]: Precision: 0.027-0.0205 Recall: 0.0861-0.1302 NDCG: 0.065-0.08 MRR: 0.0992-0.106
# [Test] Recall: 0.0758-0.1168 NDCG: 0.0584-0.0725
# Cov_A -8.3305 Cov 9.5191
# his-pred isolation 0.2181 0.1082

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_coarse_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=NFM
# Out:
# /kaggle/working/UCRS/code/UCI/user_coarse_controls
# args: Namespace(data_path='../../../data/', dataset='DIGIX', file_head='', gpu='0', model='NFM', model_path='../../FM_NFM/best_models/', topN='[10, 20]')
# NFM_DIGIX_64hidden_[4]layer_0.01lr_1024bs_[0.5,0.3]dropout_0.0lamda_1bn_500epoch_UF_min
# number of users: 7643
# number of items: 15526
# number of features: 23314
# All predicted users' number is 4768
# ------------------------------------------------------
# brefore reranking
# [Test]: Precision: 0.0263-0.0199 Recall: 0.0849-0.1259 NDCG: 0.063-0.0772 MRR: 0.0945-0.1014
# [Test] Recall: 0.0774-0.1157 NDCG: 0.0585-0.0719
# Cov_A -7.5826 Cov 10.2670
# his-pred isolation 0.2181 0.1144

# %% [markdown]
# ## user-feature fine-grained controls

# %% [markdown]
# ### UCI and changeUF for FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_fine_user_control.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# args: Namespace(data_path='../../../data/', dataset='DIGIX', file_head='', gpu='0', model='FM', model_path='../../FM_NFM/best_models/', topN='[10, 20]')
# number of users: 7643
# number of items: 15526
# number of features: 23314
# --------------------------------
# alpha 0.8
# All predicted users' number is 7643
# [Test] Recall: 0.087-0.1304 NDCG: 0.0661-0.0809
# pred diff EUC/KL 0.0500 inf 0.0516 0.0856
# Cov_A -7.1393 Cov 9.0304
# his-pred isolation 0.1154 0.0979
# --------------------------------
# alpha 0.9
# All predicted users' number is 7643
# [Test] Recall: 0.087-0.1309 NDCG: 0.0659-0.0808
# pred diff EUC/KL 0.0525 inf 0.0542 0.0918
# Cov_A -7.3317 Cov 8.8380
# his-pred isolation 0.1154 0.1073
# --------------------------------
# alpha 1.0
# All predicted users' number is 7643
# [Test] Recall: 0.0858-0.1302 NDCG: 0.0649-0.08
# pred diff EUC/KL 0.0548 inf 0.0566 0.0975
# Cov_A -7.4838 Cov 8.6859
# his-pred isolation 0.1154 0.1152

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_fine_user_control.py --model=NFM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# args: Namespace(data_path='../../../data/', dataset='DIGIX', file_head='', gpu='0', model='NFM', model_path='../../FM_NFM/best_models/', topN='[10, 20]')
# number of users: 7643
# number of items: 15526
# number of features: 23314
# --------------------------------
# alpha 0.8
# All predicted users' number is 7643
# [Test] Recall: 0.0827-0.123 NDCG: 0.0627-0.0766
# pred diff EUC/KL 0.0277 inf 0.0286 0.0394
# Cov_A -6.3720 Cov 9.7977
# his-pred isolation 0.1154 0.0654
# --------------------------------
# alpha 0.9
# All predicted users' number is 7643
# [Test] Recall: 0.0844-0.1255 NDCG: 0.0635-0.0776
# pred diff EUC/KL 0.0343 inf 0.0354 0.0506
# Cov_A -6.5258 Cov 9.6439
# his-pred isolation 0.1154 0.0844
# --------------------------------
# alpha 1.0
# All predicted users' number is 7643
# [Test] Recall: 0.0847-0.1263 NDCG: 0.063-0.0774
# pred diff EUC/KL 0.0417 inf 0.0431 0.0625
# Cov_A -6.6504 Cov 9.5193
# his-pred isolation 0.1154 0.1048

# %% [markdown]
# ### Inference for vanilla FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# args: Namespace(data_path='../../../data/', dataset='DIGIX', file_head='', gpu='0', model='FM', model_path='../../FM_NFM/best_models/', topN='[10, 20]')
# number of users: 7643
# number of items: 15526
# number of features: 23314
# [Test] Recall: 0.0861-0.1302 NDCG: 0.065-0.08
# pred diff EUC/KL 0.0550 inf 0.0568 0.0988
# Cov_A -7.4916 Cov 8.6781
# his-pred isolation 0.1154 0.1161

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=NFM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# args: Namespace(data_path='../../../data/', dataset='DIGIX', file_head='', gpu='0', model='NFM', model_path='../../FM_NFM/best_models/', topN='[10, 20]')
# number of users: 7643
# number of items: 15526
# number of features: 23314
# [Test] Recall: 0.0849-0.1259 NDCG: 0.063-0.0772
# pred diff EUC/KL 0.0423 inf 0.0436 0.0635
# Cov_A -6.6571 Cov 9.5126
# his-pred isolation 0.1154 0.1046
