# %%
# !conda env list 
# !conda create --name PYTORCHVENV python=3.7.3 -y 

# !PYTHON={/opt/conda/envs/markus_venv}/bin/python
# !conda install -y -n PYTORCHVENV pytorch=1.4.0 numpy=1.16.4 scipy pandas openpyxl seaborn matplotlib
# !conda env list
# Out:
# # conda environments:
# #
# base                     /opt/conda
#
# Retrieving notices: ...working... done
# ...
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/PYTORCHVENV
#
#   added / updated specs:
#     - python=3.7.3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
# ...

# %%
# !conda install -y gdown
# # https://drive.google.com/file/d/{FILE ID}/view?usp=sharing
# !gdown --id {1klVy8rhR2A-7-Vva0enbCZrSHB-RkXsG}

# %%
# !pip install pycuda
import pycuda
from pycuda import compiler
import pycuda.driver as drv

drv.init()
print("%d device(s) found." % drv.Device.count())
           
for ordinal in range(drv.Device.count()):
    dev = drv.Device(ordinal)
    print (ordinal, dev.name())
# Out:
# ...
# 2 device(s) found.
# 0 Tesla T4
# 1 Tesla T4

# %%
# !nvidia-smi #--query-gpu=name --format=csv,noheader
# !nvidia-smi -q # list all available GPUs + details
# !nvidia-smi -i 0x1EB810DE
# Out:
# ==============NVSMI LOG==============
#
# Timestamp                                 : Thu Jan 11 16:55:54 2024
# Driver Version                            : 535.129.03
# CUDA Version                              : 12.2
#
# Attached GPUs                             : 2
# GPU 00000000:00:04.0
#     Product Name                          : Tesla T4
#     Product Brand                         : NVIDIA
#     Product Architecture                  : Turing
#     Display Mode                          : Enabled
#     Display Active                        : Disabled
#     Persistence Mode                      : Disabled
#     Addressing Mode                       : None
#     MIG Mode
#         Current                           : N/A
#         Pending                           : N/A
#     Accounting Mode                       : Disabled
#     Accounting Mode Buffer Size           : 4000
#     Driver Model
#         Current                           : N/A
# ...

# %%
# !git clone https://github.com/WenjieWWJ/UCRS.git
# !git clone https://github.com/Experiment-Design/seedcontrol.git
import shutil

folder_path = '/kaggle/working/UCRS'

try:
    shutil.rmtree(folder_path)
    print(f'The directory {folder_path} has been successfully removed.')
except FileNotFoundError:
    print(f'The directory {folder_path} does not exist.')
except Exception as e:
    print(f'Error: {e}')

# !git clone https://github.com/Experiment-Design/UCRS.git
# Out:
# The directory /kaggle/working/UCRS has been successfully removed.
# Cloning into 'UCRS'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 170 (delta 11), reused 25 (delta 5), pack-reused 130
# Receiving objects: 100% (170/170), 79.06 MiB | 28.84 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# Updating files: 100% (123/123), done.

# %%
# !/opt/conda/envs/PYTORCHVENV/bin/python UCRS/code/FM_NFM/main.py --model=NFM --dataset=DIGIX --data_path="UCRS/data/" --hidden_factor=64 --layers='[64]' --lr=0.01 --batch_size=256 --dropout='[0.5,0.2]' --lamda=0.001 --batch_norm=1 --epochs=20 --log_name=my_log --gpu=0
# !/opt/conda/envs/PYTORCHVENV/bin/python UCRS/code/FM_NFM/main.py --model=NFM --dataset='DIGIX' --data_path="UCRS/data/"
print('DONE')
# Out:
# args: Namespace(activation_function='relu', batch_norm=1, batch_size=128, data_path='UCRS/data/', dataset='DIGIX', dropout='[0.5,0.2]', epochs=500, gpu='0', hidden_factor=64, lamda=0.0, layers='[64]', log_name='', loss_type='log_loss', lr=0.05, model='NFM', model_path='./models/', optimizer='Adagrad', out=True, pre_train=False, pre_train_model_path='./models/', rec_result_path='./rec_results/', topN='[10, 20, 50, 100]')
# number of users: 7643
# number of items: 15526
# number of features: 23314
# ^C
# Traceback (most recent call last):
#   File "UCRS/code/FM_NFM/main.py", line 138, in <module>
#     train_dataset = data_utils.FMData(train_path, user_feature, item_feature, args.loss_type, user_map_dict, item_map_dict)
#   File "/kaggle/working/UCRS/code/FM_NFM/data_utils.py", line 95, in __init__
#     self.pos_features.append(np.array(self.user_feature[userID][0]+self.item_feature[itemID][0]))
# KeyboardInterrupt
# DONE

# %%
# import os
# print(os.getcwd())
# os.chdir("/kaggle/working/")

# import sys
# sys.path.append("/kaggle/working/seedcontrol/code/globalseed")
# # sys.path.insert(0, "./kaggle/working/seedcontrol/code")
# from globalseed import random_seed

# unwanted_paths = sys.path
# for path in unwanted_paths:
#     try:
#         sys.path.remove(path)
#     except ValueError:
#         pass  # Ignore if the path is not in sys.path
# print(sys.path)
# !/opt/conda/envs/PYTORCHVENV/bin/python UCRS/code/FM_NFM/main.py --model=NFM --dataset='DIGIX' --data_path="UCRS/data/"
print('DONE')
# Out:
# args: Namespace(activation_function='relu', batch_norm=1, batch_size=128, data_path='UCRS/data/', dataset='DIGIX', dropout='[0.5,0.2]', epochs=500, gpu='0', hidden_factor=64, lamda=0.0, layers='[64]', log_name='', loss_type='log_loss', lr=0.05, model='NFM', model_path='./models/', optimizer='Adagrad', out=True, pre_train=False, pre_train_model_path='./models/', rec_result_path='./rec_results/', topN='[10, 20, 50, 100]')
# number of users: 7643
# number of items: 15526
# number of features: 23314
# data ready. costs 00: 00: 29
# begin training
# ------------------------------------------------------
# Runing Epoch 000 loss 56.9736 costs 00: 06: 04
# [Train]: RMSE: 0.8431
# [Valid]: Precision: 0.0175-0.0124-0.0086-0.0064 Recall: 0.0582-0.0815-0.1391-0.2037 NDCG: 0.0398-0.0477-0.0635-0.0783 MRR: 0.0562-0.0604-0.0646-0.0664
# [Test]: Precision: 0.0175-0.0126-0.0086-0.0065 Recall: 0.0577-0.0814-0.1356-0.2019 NDCG: 0.0398-0.048-0.063-0.0781 MRR: 0.0585-0.0629-0.0668-0.0686
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.current_device())
# Out:
# True
# 0

# %%
# !git clone  https://github.com/Experiment-Design/UCRS.git
import torch
import sys
sys.path.insert(0, './UCRS/code/FM_NFM')
import model
model_path = 'UCRS/code/FM_NFM/best_models/FM_amazon_book_64hidden_[64]layer_0.05lr_1024bs_[0.5,0.2]dropout_0.1lamda_1bn_1000epoch_best.pth'
model = torch.load(model_path)
model
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/serialization.py:888: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.10/site-packages/torch/serialization.py:888: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %%
# ad-hoc imports
# !conda install -y -n PYTORCHVENV pytorch=1.4.0 numpy=1.16.4 scipy pandas openpyxl seaborn matplotlib
# Out:
# EnvironmentLocationNotFound: Not a conda environment: /opt/conda/envs/PYTORCHVENV

# %%
import os
print(os.getcwd())
# Out:
# /kaggle/working

# %% [markdown]
# # UCI Inference

# %% [markdown]
# ## item-feature controls

# %% [markdown]
# ### Reranking

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/Reranking"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_reranking.py --model=FM --dataset=ml_1m
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/Reranking
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/Reranking"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_reranking.py --model=FM --dataset=amazon_book
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/Reranking
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/Reranking"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_reranking.py --model=FM --dataset=DIGIX
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/Reranking
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %% [markdown]
# ### Fine-grained and coarse-grained item-feature controls

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/item_controls/fine_coarse_UCI"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/C_UCI_inference.py --model=FM --dataset=ml_1m
print('\n', '='*55, '\n')
# !$PY $PATH/F_UCI_inference.py --model=NFM --dataset=amazon_book
# Out:
# /kaggle/working/UCRS/code/UCI/item_controls/fine_coarse_UCI
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory
#
# ...
#
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %% [markdown]
# ## User-feature coarse-grained controls

# %% [markdown]
# ### UCI and maskUF for FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_coarse_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_coarse_user_control.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_coarse_controls
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %% [markdown]
# ### Inference for vanilla FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_coarse_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_coarse_controls
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_coarse_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=NFM
# Out:
# /kaggle/working/UCRS/code/UCI/user_coarse_controls
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %% [markdown]
# ## user-feature fine-grained controls

# %% [markdown]
# ### UCI and changeUF for FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_fine_user_control.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/UCI_fine_user_control.py --model=NFM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %% [markdown]
# ### Inference for vanilla FM and NFM

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=FM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %%
PY="/opt/conda/envs/PYTORCHVENV/bin/python"
PATH="/kaggle/working/UCRS/code/UCI/user_fine_controls"
import os
os.chdir(PATH)
print(os.getcwd())
# !$PY $PATH/FM_NFM_inference.py --model=NFM
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# /bin/bash: line 1: /opt/conda/envs/PYTORCHVENV/bin/python: No such file or directory

# %%
# !wget https://raw.githubusercontent.com/MarkusStefan/controllable-recommender-systems/main/controllable-recommender-systems.ipynb
# Out:
# --2024-01-11 16:16:29--  https://raw.githubusercontent.com/MarkusStefan/controllable-recommender-systems/main/controllable-recommender-systems.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143904 (141K) [text/plain]
# Saving to: 'controllable-recommender-systems.ipynb'
#
# controllable-recomm 100%[===================>] 140.53K  --.-KB/s    in 0.01s
#
# 2024-01-11 16:16:29 (12.1 MB/s) - 'controllable-recommender-systems.ipynb' saved [143904/143904]

# %%
# !jupyter-nbconvert
PATH="/kaggle/working/"
print(os.getcwd())
os.chdir(PATH)
print(os.getcwd())
print(os.listdir())
# !conda install -y -n PYTORCHVENV xelatex
# !jupyter-nbconvert controllable-recommender-systems.ipynb --to html
# !jupyter-nbconvert controllable-recommender-systems.ipynb --to latex
# !jupyter-nbconvert controllable-recommender-systems.ipynb --to pdf
# Out:
# /kaggle/working/UCRS/code/UCI/user_fine_controls
# /kaggle/working
# ['UCRS', '.virtual_documents']
#
# EnvironmentLocationNotFound: Not a conda environment: /opt/conda/envs/PYTORCHVENV
#
# [NbConvertApp] WARNING | Config option `kernel_spec_manager_class` not recognized by `NbConvertApp`.
# [NbConvertApp] WARNING | pattern 'controllable-recommender-systems.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
# ...
